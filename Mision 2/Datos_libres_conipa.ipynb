# %%
import requests
import pandas as pd
url = "https://www.datos.gov.co/api/v3/views/iczg-dyt3/query.json?pageNumber=1&pageSize=10&app_token=hg1CErwWHtbRq678ROX5NLhPO"
response = requests.get(url)
data = response.json()
df = pd.json_normalize(data)
df.head()
# Out:
#                   :id           :version               :created_at  \
# 0  row-6939_sfyu-hwpm  rv-n373.kfn7~pnud  2022-05-20T22:15:07.177Z
# 1  row-iisr~74cb.m6dv  rv-232y.6xbf-awuf  2022-05-20T22:15:07.177Z
# 2  row-ngrb.qi8a-j4tn  rv-xdwb_syyy_e2b5  2022-05-20T22:15:07.177Z
# 3  row-c3z8_ta8h_aq5u  rv-uzgz.arvm-gqik  2022-05-20T22:15:07.177Z
# 4  row-pqks~j6pr.s4pp  rv-gruz.my8a.i2b4  2022-05-20T22:15:07.177Z
#
#                 :updated_at    id tipo_geometria   a_o  \
# 0  2022-05-20T22:15:07.177Z  7463        Polygon  2020
# 1  2022-05-20T22:15:07.177Z  4659        Polygon  2019
# 2  2022-05-20T22:15:07.177Z  7459        Polygon  2020
# 3  2022-05-20T22:15:07.177Z  9719        Polygon  2021
# 4  2022-05-20T22:15:07.177Z  7464        Polygon  2020
#
#                                               imagen    causa   area_ha  \
# 0  T18PTQ_20200201T153611_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.126512
# 1  T18PTQ_20190527T153621_TCI_10m.jp2 - T18PTQ_20...  Cultivo   0.14072
# ...
